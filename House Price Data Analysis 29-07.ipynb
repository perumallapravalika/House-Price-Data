# %%
import pandas as pd

hp_df=pd.read_csv('House price train.csv') #Tables in Excel are called as Data Frames in Python
hp_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
hp_df.shape #returns the no.of rows and columns from data frame
# Out:
# (1460, 81)

# %%
hp_df.columns #returns the columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
hp_df['MasVnrArea'] #If we want specific column we do this, Series are equivalent to a column in a table
# Out:
# 0       196.0
# 1         0.0
# 2       162.0
# 3         0.0
# 4       350.0
#         ...
# 1455      0.0
# 1456    119.0
# 1457      0.0
# 1458      0.0
# 1459      0.0
# Name: MasVnrArea, Length: 1460, dtype: float64

# %%
hp_df[['SaleCondition','SalePrice']] #To get 2 columns at a time
# Out:
#      SaleCondition  SalePrice
# 0           Normal     208500
# 1           Normal     181500
# 2           Normal     223500
# 3          Abnorml     140000
# 4           Normal     250000
# ...            ...        ...
# 1455        Normal     175000
# 1456        Normal     210000
# 1457        Normal     266500
# 1458        Normal     142125
# 1459        Normal     147500
#
# [1460 rows x 2 columns]

# %%
hp_df.isnull().sum()  #returns the count of missing values in each column
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %% [markdown]
# # Create a custom dataframe

# %%
stdinfo_df=pd.DataFrame({'Student_name':['Hasini','Pradeep','Pravalika'], 'Scores':[60,70,80], 'Location':['Lahore','Hyderabad','Khammam']})
stdinfo_df   #creating table in python IDE
# Out:
#   Student_name  Scores   Location
# 0       Hasini      60     Lahore
# 1      Pradeep      70  Hyderabad
# 2    Pravalika      80    Khammam

# %%
na_df=pd.DataFrame({'Column_Name' : hp_df.columns, 'MissingValue_Count' : hp_df.isnull().sum()})

na_df
# Out:
#                  Column_Name  MissingValue_Count
# Id                        Id                   0
# MSSubClass        MSSubClass                   0
# MSZoning            MSZoning                   0
# LotFrontage      LotFrontage                 259
# LotArea              LotArea                   0
# ...                      ...                 ...
# MoSold                MoSold                   0
# YrSold                YrSold                   0
# SaleType            SaleType                   0
# SaleCondition  SaleCondition                   0
# SalePrice          SalePrice                   0
#
# [81 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.boxplot(hp_df['SalePrice'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x243cb9e43d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x243cb9e4a90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x243cb9e4070>],
#  'medians': [<matplotlib.lines.Line2D at 0x243cb9ef190>],
#  'fliers': [<matplotlib.lines.Line2D at 0x243cb9ef4f0>],
#  'means': []}

# %% [markdown]
# # 31-07-21 BOX PLOT

# %%
import seaborn as sns
sns.boxplot(hp_df['SalePrice'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SalePrice'>

# %% [markdown]
# # SCATTER PLOT

# %%
plt.scatter(hp_df['LotArea'], hp_df['SalePrice'])

# %%
plt.hist(hp_df['SalePrice'])
# Out:
# (array([148., 723., 373., 135.,  51.,  19.,   4.,   3.,   2.,   2.]),
#  array([ 34900., 106910., 178920., 250930., 322940., 394950., 466960.,
#         538970., 610980., 682990., 755000.]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(hp_df['SalePrice'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %%
#find the data type in column
hp_df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
#put cont. variables and cat. variables in 2 different lists

con_cols=[]
cat_cols=[]
for col in hp_df.columns:
    if hp_df[col].dtype=='int64' or hp_df[col].dtype=='float64':
        con_cols.append(col)   #to get values into the empty list
    if hp_df[col].dtype=='object':
        cat_cols.append(col)
con_cols
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
#List Comprehension

con_cols=[col for col in hp_df.columns if hp_df[col].dtype=='int64' or hp_df[col].dtype=='float64']
cat_cols=[col for col in hp_df.columns if hp_df[col].dtype=='object']

print(con_cols)
# Out:
# ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice']

# %%
print(cat_cols)
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %%
from sklearn.model_selection import train_test_split

x_train,x_test, y_train, y_test=train_test_split(hp_df,hp_df['SalePrice'],test_size=0.2, random_state=12)
x_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 456    457          70       RM         34.0     4571   Pave  Grvl      Reg
# 313    314          20       RL        150.0   215245   Pave   NaN      IR3
# 106    107          30       RM         60.0    10800   Pave  Grvl      Reg
# 814    815          50       RL         45.0     8248   Pave  Grvl      Reg
# 976    977          30       RL         51.0     5900   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 432    433         160       RM         24.0     1920   Pave   NaN      Reg
# 1283  1284          90       RL         94.0     9400   Pave   NaN      Reg
# 1265  1266         160       FV         35.0     3735   Pave   NaN      Reg
# 1277  1278          80       RL          NaN    17871   Pave   NaN      IR1
# 1414  1415          50       RL         64.0    13053   Pave  Pave      Reg
#
# ...

# %%
import numpy as np
hp_df['SalePrice']=hp_df['SalePrice'].apply(np.log)
hp_df['SalePrice']
# Out:
# 0       12.247694
# 1       12.109011
# 2       12.317167
# 3       11.849398
# 4       12.429216
#           ...
# 1455    12.072541
# 1456    12.254863
# 1457    12.493130
# 1458    11.864462
# 1459    11.901583
# Name: SalePrice, Length: 1460, dtype: float64

# %%
def get_century(year):
    
    if year<2000:
        return '20th century'
    
    if year>=2000:
        return '21st century'
    
    hp_df['Century']=hp_df['YearBuilt'].apply(get_century)
    hp_df.to_csv('New_house_price_data.csv')

# %%
hp_df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Century'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-cfc541730592> in <module>
# ----> 1 hp_df['Century']
# ...
